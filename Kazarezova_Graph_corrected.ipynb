# %%
#Импортируем библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


#Указываем диапазон графика
plt.axis([0, 12, 0, 8.5])

#Строим кривые

#'Supervised'
a = np.arange(0., 12.) #Указываем диапазон аргумента
plt.plot(a, 0.7*a, '--', color='#000000', label='Supervised') #Указываем функцию, тип и цвет линии, подпись

#'П-model'
plt.plot([1.6, 2, 2.2, 2.3, 3, 3.9, 4, 4.3, 4.8, 5, 5.6, 5.7, 6, 7, 7.5, 8, 9, 9.5, 10, 10.4, 11, 11.6], #Эту кривую строим по точкам
         [0.4, 3.6, 5.2, 5.3, 6, 6.2, 6.2, 6.2, 6, 5.6, 4.25, 4.1, 3.5, 2.3, 2.3, 2.6, 4.4, 5.4, 6.4, 7, 7.5, 8.2],
         '-', color = '#4682B4', label='П-model')

#'Entropy minimization'
plt.plot(a, 0.4*a+2, '-', color='#228B22', label='Entropy Minimization')

#'Pseudo-Label'
b = np.arange(4, 6)
plt.plot(b, 2.9*b-12.3, '-', color = '#DC143C', label='Pseudo-Label')
plt.plot([5, 5.7], [2.2, 4], '-', color = '#DC143C')
c = np.arange(5.7, 10)
plt.plot(c, 1.2*c-2.8, '-', color = '#DC143C')

#'VAT'
plt.plot([1.6, 2, 2.2, 2.3, 3, 3.9, 4, 4.3, 4.8, 5, 5.6, 5.7, 6, 7, 7.5, 8, 9, 9.5, 10, 10.4],
         [0, 1.4, 2.3, 4.9, 5.6, 6, 6, 5.9, 5.9, 5.6, 4.15, 4.05, 3.5, 2.1, 2.2, 2.5, 4.4, 5.4, 6.9, 8.4],
         '-', color='#FFD700', label='VAT')

#'Unlabeled' ветвями вверх
d = np.arange(4, 11, 0.3)
plt.plot(d, 0.4*(d-7.5)**2+1.2, 'o', color='#DCDCDC', markersize=4, #markersize - размер точек
         markeredgecolor='#808080', markeredgewidth=0.5, label='Unlabeled') #markeredgecolor и markeredgewidth - цвет и толщина границы
e = np.arange(4.5, 10.5, 0.4)
plt.plot(e, 0.4*(e-7.5)**2+0.7, 'o', color='#DCDCDC', markersize=4, markeredgecolor='#808080', markeredgewidth=0.5)
plt.plot(e, 0.4*(e-7.5)**2+1.7, 'o', color='#DCDCDC', markersize=4, markeredgecolor='#808080', markeredgewidth=0.5)
plt.plot(e, 0.4*(e-7)**2+1.2, 'o', color='#DCDCDC', markersize=4, markeredgecolor='#808080', markeredgewidth=0.5)
plt.plot(e, 0.4*(e-8)**2+1.2, 'o', color='#DCDCDC', markersize=4, markeredgecolor='#808080', markeredgewidth=0.5)

#'Unlabeled' ветвями вниз
z = np.arange(0.5, 7.5, 0.3)
plt.plot(z, (-0.4)*(z-4)**2+7.5, 'o', color='#DCDCDC', markersize=4, markeredgecolor='#808080', markeredgewidth=0.5)
f = np.arange(1, 7, 0.4)
plt.plot(f, (-0.4)*(f-4)**2+8, 'o', color='#DCDCDC', markersize=4, markeredgecolor='#808080', markeredgewidth=0.5)
plt.plot(f, (-0.4)*(f-4)**2+7, 'o', color='#DCDCDC', markersize=4, markeredgecolor='#808080', markeredgewidth=0.5)
plt.plot(f, (-0.4)*(f-4.5)**2+7.5, 'o', color='#DCDCDC', markersize=4, markeredgecolor='#808080', markeredgewidth=0.5)
plt.plot(f, (-0.4)*(f-3.5)**2+7.5, 'o', color='#DCDCDC', markersize=4, markeredgecolor='#808080', markeredgewidth=0.5)

#'Class 1'
plt.plot([1.1, 3.9, 4.8], [4.2, 7.2, 7.5], 'o', color='#000000', markersize=15, label='Class 1')

#'Class 2'
plt.plot([5.6, 8, 9.5], [1.9, 0.9, 2.4], 'o', color='#FFFFFF', markersize=15, 
         markeredgecolor='#000000', markeredgewidth=2, label='Class 2')


#Убираем тики
plt.tick_params(axis='x',which='both',bottom=False)
plt.tick_params(axis='y',which='both',left=False)

#Указываем параметры легенды
leg=plt.legend(borderpad=1.5, facecolor='#ffffff', bbox_to_anchor=(1, 1), prop={'size': 14})

#Показать график
plt.show()
